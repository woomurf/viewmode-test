# %% [markdown]
# # display data

# %% [markdown]
# ### image/png

# %%
from IPython.display import Image, display

display(Image(filename="./dog.png"))

# %% [markdown]
# ### image/png metadata

# %%
from IPython.display import Image, display

display(Image(filename="./dog.png", width=200))

# %% [markdown]
# ### image/jpg

# %%
from IPython.display import Image, display

display(Image(filename="./TheCat.jpg"))

# %% [markdown]
# ### image/jpg metadata

# %%
from IPython.display import Image, display

display(Image(filename="./TheCat.jpg", width=100))

# %% [markdown]
# ### text/html

# %%
from IPython.display import display, FileLink

local_file = FileLink('./GPU.xlsx', result_html_prefix="Click here to download: ")
display(local_file)
# Out:
# /workspace/GPU.xlsx

# %% [markdown]
# ### text/markdown

# %%
from IPython.display import display, Markdown
display(Markdown("# Hello World!"))
display(Markdown("## Hello World!"))
display(Markdown("### Hello World!"))
# Out:
# # Hello World!
# ## Hello World!
# ### Hello World!

# %% [markdown]
# ### text/latex

# %%
from IPython.display import display, Math, Latex
display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))
display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))
display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))
# Out:
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$

# %% [markdown]
# ### text/plain

# %%
from tqdm.notebook import tqdm
for group in tqdm(range(10)):
    continue
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
